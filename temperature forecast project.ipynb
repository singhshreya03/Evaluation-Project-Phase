# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing

# %matplotlib inline

# %%
weather_df = pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Temperature%20Forecast/temperature.csv',)
weather_df.head(5)
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
# ...

# %%
weather_df.columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %%
weather_df.shape
# Out:
# (7752, 25)

# %%
weather_df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7750.000000   7682.000000   7682.000000  7677.000000  7677.000000
# mean     13.000000     29.768211     23.225059    56.759372    88.374804
# std       7.211568      2.969999      2.413961    14.668111     7.192004
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    45.963543    84.222862
# 50%      13.000000     29.900000     23.400000    55.039024    89.793480
# 75%      19.000000     32.000000     24.900000    67.190056    93.743629
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7677.000000       7677.000000  7677.000000  7677.000000
# mean          29.613447         23.512589     7.097875    62.505019
# std            2.947191          2.345347     2.183836    33.730589
# ...

# %%
weather_df.isnull().any()
# Out:
# station              True
# Date                 True
# Present_Tmax         True
# Present_Tmin         True
# LDAPS_RHmin          True
# LDAPS_RHmax          True
# LDAPS_Tmax_lapse     True
# LDAPS_Tmin_lapse     True
# LDAPS_WS             True
# LDAPS_LH             True
# LDAPS_CC1            True
# LDAPS_CC2            True
# LDAPS_CC3            True
# LDAPS_CC4            True
# LDAPS_PPT1           True
# LDAPS_PPT2           True
# LDAPS_PPT3           True
# LDAPS_PPT4           True
# lat                 False
# lon                 False
# DEM                 False
# Slope               False
# Solar radiation     False
# Next_Tmax            True
# Next_Tmin            True
# dtype: bool

# %%
weather_df = weather_df.dropna()

# %%
weather_df.replace({"Next_Tmin":{'N':0, 'Y':1}}, inplace=True)

# %%
weather_df.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
# ...

# %%
weather_df['LDAPS_PPT2'].value_counts()
# Out:
# LDAPS_PPT2
# 0.000000    5094
# 0.001953       7
# 0.000040       3
# 0.000781       3
# 0.000086       2
#             ...
# 0.007427       1
# 0.087218       1
# 0.000695       1
# 0.047651       1
# 0.247997       1
# Name: count, Length: 2479, dtype: int64

# %%
weather_df_num=weather_df.loc[:,['Present_Tmax','Present_Tmin','LDAPS_RHmin','LDAPS_RHmax','LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse','LDAPS_WS', 'LDAPS_LH', 'LDAPS_CC1','LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon', 'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin']]
weather_df_num.head()
# Out:
#    Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0          28.7          21.4    58.255688    91.116364         28.074101
# 1          31.9          21.6    52.263397    90.604721         29.850689
# 2          31.6          23.3    48.690479    83.973587         30.091292
# 3          32.0          23.4    58.239788    96.483688         29.704629
# 4          31.4          21.9    56.174095    90.155128         29.113934
#
#    LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  LDAPS_PPT2  LDAPS_PPT3  \
# 0         23.006936  6.818887   69.451805   0.233947         0.0         0.0
# 1         24.035009  5.691890   51.937448   0.225508         0.0         0.0
# 2         24.565633  6.138224   20.573050   0.209344         0.0         0.0
# 3         23.326177  5.650050   65.727144   0.216372         0.0         0.0
# 4         23.486480  5.735004  107.965535   0.151407         0.0         0.0
#
# ...

# %%
weather_df_num.shape
# Out:
# (7588, 19)

# %%
weather_df_num.columns
# Out:
# Index(['Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin', 'LDAPS_RHmax',
#        'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH',
#        'LDAPS_CC1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %%
weather_df_num.plot(subplots=True, figsize=(25,20))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >], dtype=object)

# %%
weather_df_num['2013':'2014'].resample('D').fillna(method='pad').plot(subplots=True, figsize=(25,20))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 weather_df_num['2013':'2014'].resample('D').fillna(method='pad').plot(subplots=True, figsize=(25,20))
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4085, in DataFrame.__getitem__(self, key)
#    4083 # Do we have a slicer (on rows)?
#    4084 if isinstance(key, slice):
# -> 4085     return self._getitem_slice(key)
#    4087 # Do we have a (boolean) DataFrame?
#    4088 if isinstance(key, DataFrame):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:4349, in NDFrame._getitem_slice(self, key)
#    4344 """
#    4345 __getitem__ for the case where the key is a slice object.
#    4346 """
#    4347 # _convert_slice_indexer to determine if this slice is positional
#    4348 #  or label based, and if the latter, convert to positional
# ...

# %%
weather_df_num.hist(bins=10,figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'Present_Tmax'}>,
#         <Axes: title={'center': 'Present_Tmin'}>,
#         <Axes: title={'center': 'LDAPS_RHmin'}>,
#         <Axes: title={'center': 'LDAPS_RHmax'}>],
#        [<Axes: title={'center': 'LDAPS_Tmax_lapse'}>,
#         <Axes: title={'center': 'LDAPS_Tmin_lapse'}>,
#         <Axes: title={'center': 'LDAPS_WS'}>,
#         <Axes: title={'center': 'LDAPS_LH'}>],
#        [<Axes: title={'center': 'LDAPS_CC1'}>,
#         <Axes: title={'center': 'LDAPS_PPT2'}>,
#         <Axes: title={'center': 'LDAPS_PPT3'}>,
#         <Axes: title={'center': 'LDAPS_PPT4'}>],
#        [<Axes: title={'center': 'lat'}>, <Axes: title={'center': 'lon'}>,
#         <Axes: title={'center': 'DEM'}>,
#         <Axes: title={'center': 'Slope'}>],
#        [<Axes: title={'center': 'Solar radiation'}>,
#         <Axes: title={'center': 'Next_Tmax'}>,
#         <Axes: title={'center': 'Next_Tmin'}>, <Axes: >]], dtype=object)

# %%
weth=weather_df_num['2013':'2017']
weth.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 weth=weather_df_num['2013':'2017']
#       2 weth.head()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4085, in DataFrame.__getitem__(self, key)
#    4083 # Do we have a slicer (on rows)?
#    4084 if isinstance(key, slice):
# -> 4085     return self._getitem_slice(key)
#    4087 # Do we have a (boolean) DataFrame?
#    4088 if isinstance(key, DataFrame):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:4349, in NDFrame._getitem_slice(self, key)
#    4344 """
#    4345 __getitem__ for the case where the key is a slice object.
#    4346 """
#    4347 # _convert_slice_indexer to determine if this slice is positional
#    4348 #  or label based, and if the latter, convert to positional
# ...

# %%
weather_y=weather_df_num.pop("Next_Tmax")
weather_x=weather_df_num

# %%
train_X,test_X,train_y,test_y=train_test_split(weather_x,weather_y,test_size=0.2,random_state=4)

# %%
train_X.shape
# Out:
# (6070, 18)

# %%
train_y.shape
# Out:
# (6070,)

# %%
train_y.head()
# Out:
# 6276    32.0
# 404     26.7
# 5573    35.2
# 278     24.7
# 3334    33.0
# Name: Next_Tmax, dtype: float64

# %%
plt.scatter(weth.maxtempC, weth.Next_Tmax)
plt.xlabel("Maximum Temperature")
plt.ylabel("Temperature")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 plt.scatter(weth.maxtempC, weth.Next_Tmax)
#       2 plt.xlabel("Maximum Temperature")
#       3 plt.ylabel("Temperature")
#
# NameError: name 'weth' is not defined

# %%
model=LinearRegression()
model.fit(train_X,train_y)
# Out:
# LinearRegression()

# %%
prediction = model.predict(test_X)

# %%
print('Variance score: %.2f' % model.score(test_X, test_y))
# Out:
# Variance score: 0.78

# %%
for i in range(len(prediction)):
  prediction[i]=round(prediction[i],2)
pd.DataFrame({'Actual':test_y,'Prediction':prediction,'diff':(test_y-prediction)})
# Out:
#       Actual  Prediction  diff
# 3071    30.7       30.37  0.33
# 4394    29.4       27.08  2.32
# 5065    23.5       25.33 -1.83
# 4590    29.7       29.34  0.36
# 4215    31.1       31.87 -0.77
# ...      ...         ...   ...
# 5325    28.0       28.46 -0.46
# 6496    32.4       31.62  0.78
# 1229    33.7       31.90  1.80
# 3279    25.6       28.00 -2.40
# 7438    28.6       31.47 -2.87
#
# [1518 rows x 3 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
regressor=DecisionTreeRegressor(random_state=0)
regressor.fit(train_X,train_y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
prediction2=regressor.predict(test_X)
np.mean(np.absolute(prediction2-test_y))
# Out:
# 1.1339262187088273

# %%
print('Variance score: %.2f' % regressor.score(test_X, test_y))
# Out:
# Variance score: 0.74

# %%
for i in range(len(prediction2)):
  prediction2[i]=round(prediction2[i],2)
pd.DataFrame({'Actual':test_y,'Prediction':prediction2,'diff':(test_y-prediction2)})
# Out:
#       Actual  Prediction  diff
# 3071    30.7        29.5   1.2
# 4394    29.4        25.4   4.0
# 5065    23.5        22.7   0.8
# 4590    29.7        30.1  -0.4
# 4215    31.1        30.4   0.7
# ...      ...         ...   ...
# 5325    28.0        29.4  -1.4
# 6496    32.4        31.6   0.8
# 1229    33.7        30.5   3.2
# 3279    25.6        29.7  -4.1
# 7438    28.6        28.3   0.3
#
# [1518 rows x 3 columns]

# %%
from sklearn.metrics import r2_score

# %%
print("Mean absolute error: %.2f" % np.mean(np.absolute(prediction - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((prediction - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y,prediction ) )
# Out:
# Mean absolute error: 1.10
# Residual sum of squares (MSE): 2.09
# R2-score: 0.78
